# %% [markdown]
# #### P-1.29
# Write a Python program that outputs all possible strings formed by using the characters c , a , t , d , o ,and g exactly once.

# %%
from itertools import permutations
def all_possible_strings(characters=['c', 'a', 't', 'd', 'o', 'g']):
    strings = []
    for i in range(1, len(characters)):
        strings += [''.join(x) for x in permutations(characters, i)]
    return strings
all_possible_strings()
# Out:
# ['c',
#  'a',
#  't',
#  'd',
#  'o',
#  'g',
#  'ca',
#  'ct',
#  'cd',
#  'co',
#  'cg',
#  'ac',
#  'at',
#  'ad',
#  'ao',
#  'ag',
#  'tc',
#  'ta',
#  'td',
#  'to',
#  'tg',
#  'dc',
#  'da',
#  'dt',
#  'do',
#  'dg',
#  'oc',
#  'oa',
#  'ot',
#  'od',
#  'og',
#  'gc',
#  'ga',
#  'gt',
#  'gd',
#  'go',
#  'cat',
#  'cad',
#  'cao',
#  'cag',
#  'cta',
#  'ctd',
#  'cto',
#  'ctg',
#  'cda',
#  'cdt',
#  'cdo',
#  'cdg',
#  'coa',
#  'cot',
#  'cod',
#  'cog',
#  'cga',
#  'cgt',
#  'cgd',
#  'cgo',
#  'act',
#  'acd',
#  'aco',
#  'acg',
#  'atc',
#  'atd',
#  'ato',
#  'atg',
#  'adc',
#  'adt',
#  'ado',
#  'adg',
#  'aoc',
#  'aot',
#  'aod',
#  'aog',
#  'agc',
#  'agt',
#  'agd',
#  'ago',
#  'tca',
#  'tcd',
#  'tco',
#  'tcg',
#  'tac',
#  'tad',
#  'tao',
#  'tag',
#  'tdc',
#  'tda',
#  'tdo',
#  'tdg',
#  'toc',
#  'toa',
#  'tod',
#  'tog',
#  'tgc',
#  'tga',
#  'tgd',
#  'tgo',
#  'dca',
#  'dct',
#  'dco',
#  'dcg',
#  'dac',
#  'dat',
#  'dao',
#  'dag',
# ...

# %% [markdown]
# #### P-1.30
#
# Write a Python program that can take a positive integer greater than 2 as input and write out the number of times one must repeatedly divide this number by 2 before getting a value less than 2.

# %%
def sqrt_approximation(n):
    div = 0
    while n >= 2:
        n /= 2
        div += 1
    return div
print(sqrt_approximation(3))
print(sqrt_approximation(4))
print(sqrt_approximation(5))
print(sqrt_approximation(6))
print(sqrt_approximation(7))
print(sqrt_approximation(8))
# Out:
# 1
# 2
# 2
# 2
# 2
# 3

# %% [markdown]
# #### P-1.31
# Write a Python program that can “make change.” Your program should take two numbers as input, one that is a monetary amount charged and the other that is a monetary amount given. It should then return the number of each kind of bill and coin to give back as change for the difference between the amount given and the amount charged. The values assigned to the bills and coins can be based on the monetary system of any current or former government. Try to design your program so that it returns as few bills and coins as possible.

# %%
def make_change(charge, given):
    denominations = {10000: '$100', 5000: '$50', 2000: '$20', 1000: '$10', 500: '$5', 100: '$1',
                     25: '25c', 10: '10c', 5: '5c', 1: '1c'}
    diff = (given - charge) * 100
    if diff < 0:
        raise ValueError('The given amount is less than the charge!')
    elif diff == 0:
        return None
    else:
        change = {}
        for key in sorted(denominations.keys(), reverse=True):
            num = diff // key
            if num > 0:
                change[denominations[key]] = num
                diff -= key * num
        return change
try:
    make_change(100, 75)
except ValueError as e:
    print(e)
print(make_change(50, 50))
print(make_change(37.64, 50))
# Out:
# The given amount is less than the charge!
# None
# 1236.0
# 1236.0
# 1236.0
# 1236.0
# 236.0
# 236.0
# 36.0
# 11.0
# 1.0
# 1.0
# {'$10': 1.0, '$1': 2.0, '25c': 1.0, '10c': 1.0, '1c': 1.0}

# %% [markdown]
# #### P-1.32
# Write a Python program that can simulate a simple calculator, using the console as the exclusive input and output device. That is, each input to the calculator, be it a number, like 12.34 or 1034, or an operator, like + or =, can be done on a separate line. After each such input, you should output to the Python console what would be displayed on your calculator.

# %% [markdown]
# #### P-1.33
# Write a Python program that simulates a handheld calculator.

# %% [markdown]
# #### P-1.34
# A common punishment for school children is to write out a sentence multiple times. Write a Python stand-alone program that will write out the following sentence one hundred times: “I will never spam my friends again.” Your program should number each of the sentences and it should make eight different random-looking typos.

# %%
from random import random, randint
def complete_punishment(sentence, repetitions=100, errors=8):
    counter = 0
    mistakes = 0
    while counter < repetitions:
        if mistakes < errors:
            make_error = random()
            if make_error < 0.5:
                index = randint(0, len(sentence))
                char = randint(32, 126)
                curr_sentence = sentence[:index] + chr(char) + sentence[index+1:]
                mistakes += 1
            else:
                curr_sentence = sentence
        else:
            curr_sentence = sentence
        print(curr_sentence)
        counter +=1
complete_punishment('I will never spam my friends again.')
# Out:
# I will never spam my *riends again.
# I will never spam my friends again.
# I will nzver spam my friends again.
# I will neeer spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my frien(s again.
# I will never spam my friends again.
# I will nnver spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my frien4s again.
# I will never spam my friends again.
# I aill never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends agaPn.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# I will never spam my friends again.
# ...

# %% [markdown]
# #### P-1.35
# The birthday paradox says that the probability that two people in a room will have the same birthday is more than half, provided n, the number of people in the room, is more than 23. This property is not really a paradox, but many people find it surprising. Design a Python program that can test this paradox by a series of experiments on randomly generated birthdays, which test this paradox for n = 5,10,15,20,...,100.

# %%
from random import randint
def test_birthday_paradox(n):
    birthdays = []
    while len(birthdays) < n:
        birthdays.append(randint(1, 365))
    repeats = {}
    max_repeat = 0
    for day in sorted(set(birthdays)):
        count = birthdays.count(day)
        if count > 1:
            repeats[day] = count
            if count > max_repeat:
                max_repeat = count
    print('{} repeated birthdays with maximum {} people sharing a birthday!'.format(len(repeats), max_repeat))
for i in range(5, 101, 5):
    test_birthday_paradox(i)
# Out:
# 0 repeated birthdays with maximum 0 people sharing a birthday!
# 0 repeated birthdays with maximum 0 people sharing a birthday!
# 0 repeated birthdays with maximum 0 people sharing a birthday!
# 0 repeated birthdays with maximum 0 people sharing a birthday!
# 0 repeated birthdays with maximum 0 people sharing a birthday!
# 0 repeated birthdays with maximum 0 people sharing a birthday!
# 2 repeated birthdays with maximum 2 people sharing a birthday!
# 1 repeated birthdays with maximum 2 people sharing a birthday!
# 4 repeated birthdays with maximum 2 people sharing a birthday!
# 2 repeated birthdays with maximum 2 people sharing a birthday!
# 2 repeated birthdays with maximum 2 people sharing a birthday!
# 2 repeated birthdays with maximum 3 people sharing a birthday!
# 5 repeated birthdays with maximum 2 people sharing a birthday!
# 5 repeated birthdays with maximum 2 people sharing a birthday!
# 7 repeated birthdays with maximum 3 people sharing a birthday!
# ...

# %% [markdown]
# #### C-1.36
# Write a Python program that inputs a list of words, separated by white- space, and outputs how many times each word appears in the list. You need not worry about efficiency at this point, however, as this topic is something that will be addressed later in this book.

# %%
def count_words(inputs):
    word_list = inputs.split()
    unique_words = set(word_list)
    return {w: word_list.count(w) for w in unique_words}
lorem_ipsum1 = '''Lorem ipsum dolor sit amet, consectetur adipiscing elit. Cras sollicitudin ultrices velit. 
Suspendisse ultrices id enim sit amet consequat. Nunc vel magna nec dui pulvinar aliquam. Morbi purus libero, 
pellentesque ut dignissim ac, accumsan a velit. Donec purus dolor, scelerisque vel tempus eget, feugiat nec nibh. 
Vestibulum tincidunt tellus risus, et auctor purus pretium nec. Aliquam tempus augue eu justo ornare, a rhoncus 
magna euismod. Aliquam id accumsan ante.'''
lorem_ipsum2 = '''Morbi orci tellus, fermentum quis efficitur ac, pulvinar ut mauris. In neque arcu, 
vestibulum vel varius ut, molestie ac ex. Praesent ac arcu eget lacus placerat lobortis scelerisque vel tellus. 
Quisque et consequat leo. Nam et varius quam. Nulla facilisi. Morbi tincidunt sagittis arcu, ut molestie elit 
vulputate sed. Donec nulla ligula, malesuada in ex nec, pharetra fermentum velit. Duis risus erat, 
auctor at ornare et, maximus quis ligula.'''
lorem_ipsum3 = '''Nunc quis ligula et odio finibus pulvinar. Integer semper faucibus odio. 
Phasellus consequat gravida dui, luctus laoreet ipsum feugiat vel. 
Suspendisse hendrerit ligula vel velit luctus gravida. Fusce ut venenatis magna. 
In interdum rutrum elementum. Vestibulum felis massa, semper sed congue quis, auctor at justo. 
Suspendisse consectetur tristique mi, ut varius metus. Vestibulum at nisl at lectus volutpat auctor.'''
lorem_ipsum4 = '''Duis consectetur vulputate est, suscipit accumsan eros vulputate ac. 
Praesent scelerisque ligula enim, ac imperdiet augue finibus ut. Sed sollicitudin sodales elit eget tincidunt. 
Sed non sodales nisl, ac sagittis tortor. Morbi luctus diam lectus, non finibus eros pulvinar et. 
Etiam id maximus urna. Quisque tristique elementum urna, eget finibus magna ultrices sit amet. 
Sed iaculis, magna porttitor cursus volutpat, lacus enim blandit massa, vitae lobortis felis sem malesuada velit. 
Aliquam a tincidunt quam. Pellentesque sed interdum turpis.'''
lorem_ipsum5 = '''Cras posuere ante sit amet dui consequat scelerisque. 
Aliquam tristique malesuada egestas. Maecenas dictum lectus quam, non facilisis ex tincidunt eu. 
In maximus facilisis risus quis viverra. Vestibulum a enim non turpis interdum sollicitudin. 
Curabitur rutrum enim ut nulla pulvinar, sit amet molestie libero malesuada. 
Maecenas et diam quis nisi molestie dapibus. Nam dignissim purus sed nisl pulvinar elementum. 
Phasellus cursus quam risus, sed dapibus leo hendrerit sit amet. Vivamus eget hendrerit eros, 
eu fringilla eros. Proin porta quam vitae tellus maximus, et convallis dolor suscipit. 
Integer rutrum augue ac maximus cursus.'''
print(count_words(lorem_ipsum1))
print(count_words(lorem_ipsum2))
print(count_words(lorem_ipsum3))
print(count_words(lorem_ipsum4))
print(count_words(lorem_ipsum5))
# Out:
# {'id': 2, 'sit': 2, 'ultrices': 2, 'tempus': 2, 'amet,': 1, 'elit.': 1, 'nibh.': 1, 'ornare,': 1, 'pulvinar': 1, 'consequat.': 1, 'aliquam.': 1, 'Vestibulum': 1, 'augue': 1, 'justo': 1, 'rhoncus': 1, 'euismod.': 1, 'tellus': 1, 'Cras': 1, 'risus,': 1, 'libero,': 1, 'dignissim': 1, 'Suspendisse': 1, 'eu': 1, 'adipiscing': 1, 'ante.': 1, 'dui': 1, 'sollicitudin': 1, 'magna': 2, 'scelerisque': 1, 'Donec': 1, 'accumsan': 2, 'enim': 1, 'feugiat': 1, 'pretium': 1, 'dolor': 1, 'nec.': 1, 'Morbi': 1, 'vel': 2, 'nec': 2, 'Nunc': 1, 'eget,': 1, 'ipsum': 1, 'amet': 1, 'consectetur': 1, 'a': 2, 'velit.': 2, 'pellentesque': 1, 'Aliquam': 2, 'ut': 1, 'purus': 3, 'auctor': 1, 'et': 1, 'ac,': 1, 'tincidunt': 1, 'dolor,': 1, 'Lorem': 1}
# ...
